# %%
import pandas as pd

df = pd.read_csv("cleaned_data_transformed.csv")
df.head()
# Out:
#       realSum    logSum  room_type_apt  room_type_private  room_type_shared  \
# 0  194.033698  5.268032              0                  1                 0
# 1  344.245776  5.841356              0                  1                 0
# 2  264.101422  5.576333              0                  1                 0
# 3  433.529398  6.071960              0                  1                 0
# 4  485.552926  6.185288              0                  1                 0
#
#    person_capacity  is_superhost  multi  biz  cleanliness_rating  \
# 0              2.0             0      1    0                10.0
# 1              4.0             0      0    0                 8.0
# 2              2.0             0      0    1                 9.0
# 3              4.0             0      0    1                 9.0
# 4              2.0             1      0    0                10.0
#
#    guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# ...
